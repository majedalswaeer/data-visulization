# %% [markdown]
# # Data Visulization
# - The data set used here was imported from seaborn library
# - Author Majed Al-swaeer
# - Date: 27/10/2021

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## `Selecting data set from seaborn`

# %%
sns.get_dataset_names()
df=sns.load_dataset('titanic')
my_df=df[df['survived']==1]
my_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### `The data presented above has been filtered to include only those who survived the titanic crises.`

# %%
my_df.describe()
# Out:
#        survived      pclass         age       sibsp       parch        fare
# count     342.0  342.000000  290.000000  342.000000  342.000000  342.000000
# mean        1.0    1.950292   28.343690    0.473684    0.464912   48.395408
# std         0.0    0.863321   14.950952    0.708688    0.771712   66.596998
# min         1.0    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%         1.0    1.000000   19.000000    0.000000    0.000000   12.475000
# 50%         1.0    2.000000   28.000000    0.000000    0.000000   26.000000
# 75%         1.0    3.000000   36.000000    1.000000    1.000000   57.000000
# max         1.0    3.000000   80.000000    4.000000    5.000000  512.329200

# %% [markdown]
# ### `From the descripton above we can see that 342 persons has been survived and the older one was 80 years old`

# %%
d_1=sns.countplot(data=my_df,x='class')

# %% [markdown]
# ### `From the figure above we can notice that the most survivers was from the first class, because the lifeboats was easy accses for them.`

# %%
d_2=sns.countplot(data=my_df,x='sex')

# %% [markdown]
# ### `we can notice above that the females almost double the males was survived.`

# %%
d_3=my_df.groupby(['sex'],as_index=False).mean()
sns.barplot(data=d_3,x='sex',y="age")
females=my_df['sex']=='female'
males=my_df['sex']=='male'
my_df[females].describe()
my_df[males].describe()
# Out:
#        survived      pclass        age       sibsp       parch        fare
# count     109.0  109.000000  93.000000  109.000000  109.000000  109.000000
# mean        1.0    2.018349  27.276022    0.385321    0.357798   40.821484
# std         0.0    0.922774  16.504803    0.636952    0.645826   71.355967
# min         1.0    1.000000   0.420000    0.000000    0.000000    0.000000
# 25%         1.0    1.000000  18.000000    0.000000    0.000000    9.500000
# 50%         1.0    2.000000  28.000000    0.000000    0.000000   26.287500
# 75%         1.0    3.000000  36.000000    1.000000    1.000000   39.000000
# max         1.0    3.000000  80.000000    4.000000    2.000000  512.329200

# %% [markdown]
# ### `We can notice that almost of the survivers are youngs due to the mean age of females and males`
# ### `233 females and 109 males was survived `
